# %% [markdown]
# ### Imports and load yeast dataset.

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np
import torchvision
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Resize, Compose, Pad, RandomCrop, RandomHorizontalFlip, Normalize
from torch.utils.data import random_split, DataLoader
import torchvision.utils
import torch.nn as nn
import torch.nn.functional as F
from ignite.engine import Engine, Events
from ignite.handlers import EarlyStopping

# Define a custom transform that resizes and pads images to ensure they are 30x30 pixels
custom_transform = Compose([
    Resize((30, 30)),  # This resizes to 30x30 directly 
    ToTensor()
])

# Load dataset with custom transform
dataset = ImageFolder('yeast-class', transform=custom_transform)

# %% [markdown]
# ### Split dataset into training and validation sets.

# %%
dataset_size = len(dataset)
train_size = int(0.6 * dataset_size)
val_size = int(0.2 * dataset_size)
test_size = dataset_size - train_size - val_size
train_ds, val_ds, test_ds = random_split(dataset, [train_size, val_size, test_size])

# %% [markdown]
# ### Add GPU support for faster training. The Metal Perforamce Shaders (MPS) are used for GPU acceleration.

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.backends.mps.is_available():
        return torch.device('mps')
    else:
        return torch.device('cpu')
   
device = get_default_device()
device
# Out:
# device(type='mps')

# %% [markdown]
# ### Function for printing the dataset labels.

# %%
def dataset_contents(dataset):
    ''' Prints the amount of data for each class in the dataset'''
    classes = dataset.classes
    num_classes = len(classes)
    img_dict = {}
    # Initialize dictionary
    for i in range(num_classes):
        img_dict[classes[i]] = 0
    # Count the amount of data for each class
    for i in range(dataset_size):
        img, label = dataset[i]
        img_dict[classes[label]] += 1
    # Finally prints the amount of data for each class
    print("Classes and amount of data: ", img_dict)

# %% [markdown]
# ### Function for predicting a single image

# %%
def predict_image(img, model):
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    # Pick index with highest probability
    _, preds  = torch.max(yb, dim=1)
    # Retrieve the class label
    return dataset.classes[preds[0].item()]

# %% [markdown]
# ### Setup parameters

# %%
batch_size = 64
num_epochs = 200
lr = 0.00001
weight_decay = 0.00001
opt_func = torch.optim.Adam

# %% [markdown]
# ### Setup dataloader

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle=True)
val_dl = DataLoader(val_ds, batch_size * 2, shuffle=True)
test_dl = DataLoader(test_ds, batch_size * 2, shuffle=True)

# %% [markdown]
# ### Define variabels for model

# %%
input_size = 30*30*3
output_size = dataset.classes

# %% [markdown]
# ### Define baseclass

# %%
class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        images, labels = images.to(device), labels.to(device)
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch
        images, labels = images.to(device), labels.to(device)
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['train_loss'], result['val_loss'], result['val_acc']))

# %% [markdown]
# ### Define accuracy metric

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %% [markdown]
# # Extends the base class for yeast dataset.

# %%
class Yeast_Model(ImageClassificationBase):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 64 x 16 x 16

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 128 x 8 x 8

            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 256 x 4 x 4

            nn.Flatten(), 
            nn.Linear(2304, 1024), # 256 * 4 * 4 and 1024 for the next layer
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 2)) # two classes. Sick and healthy

        
    def forward(self, xb):
        return self.network(xb)

# %% [markdown]
# ### Initialize the model

# %%
model = Yeast_Model()

# %% [markdown]
# ### Setup traning function

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.Adam, weight_decay=0):
    history = []
    optimizer = opt_func(model.parameters(), lr, weight_decay=weight_decay)
    for epoch in range(epochs):
        # Training Phase
        model.train()
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
            
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %% [markdown]
# ### Test for 1 run. expted acc <= 0.5

# %%
model = Yeast_Model()
model.to(device)
# Out:
# Yeast_Model(
#   (network): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Flatten(start_dim=1, end_dim=-1)
#     (16): Linear(in_features=2304, out_features=1024, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=1024, out_features=512, bias=True)
#     (19): ReLU()
#     (20): Linear(in_features=512, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ### Train the model

# %%
torch.mps.empty_cache()
torch.mps.synchronize()
history = fit(num_epochs, lr, model, train_dl, val_dl, opt_func, weight_decay)
# Out:
# Epoch [0], train_loss: 0.6920, val_loss: 0.6947, val_acc: 0.4917
# Epoch [1], train_loss: 0.6924, val_loss: 0.6947, val_acc: 0.4917
# Epoch [2], train_loss: 0.6920, val_loss: 0.6946, val_acc: 0.4917
# Epoch [3], train_loss: 0.6913, val_loss: 0.6945, val_acc: 0.4917
# Epoch [4], train_loss: 0.6913, val_loss: 0.6945, val_acc: 0.4917
# Epoch [5], train_loss: 0.6921, val_loss: 0.6945, val_acc: 0.4917
# Epoch [6], train_loss: 0.6923, val_loss: 0.6944, val_acc: 0.4917
# Epoch [7], train_loss: 0.6907, val_loss: 0.6941, val_acc: 0.4917
# Epoch [8], train_loss: 0.6917, val_loss: 0.6939, val_acc: 0.4917
# Epoch [9], train_loss: 0.6905, val_loss: 0.6936, val_acc: 0.4917
# Epoch [10], train_loss: 0.6906, val_loss: 0.6931, val_acc: 0.4917
# Epoch [11], train_loss: 0.6898, val_loss: 0.6924, val_acc: 0.4917
# Epoch [12], train_loss: 0.6893, val_loss: 0.6914, val_acc: 0.4917
# Epoch [13], train_loss: 0.6873, val_loss: 0.6898, val_acc: 0.4917
# Epoch [14], train_loss: 0.6866, val_loss: 0.6878, val_acc: 0.4917
# Epoch [15], train_loss: 0.6836, val_loss: 0.6848, val_acc: 0.4917
# Epoch [16], train_loss: 0.6813, val_loss: 0.6813, val_acc: 0.5667
# Epoch [17], train_loss: 0.6768, val_loss: 0.6767, val_acc: 0.6667
# Epoch [18], train_loss: 0.6718, val_loss: 0.6708, val_acc: 0.7250
# Epoch [19], train_loss: 0.6642, val_loss: 0.6632, val_acc: 0.7250
# Epoch [20], train_loss: 0.6571, val_loss: 0.6531, val_acc: 0.7083
# Epoch [21], train_loss: 0.6470, val_loss: 0.6405, val_acc: 0.7167
# Epoch [22], train_loss: 0.6316, val_loss: 0.6226, val_acc: 0.7667
# Epoch [23], train_loss: 0.6133, val_loss: 0.6005, val_acc: 0.7500
# Epoch [24], train_loss: 0.5889, val_loss: 0.5753, val_acc: 0.7667
# Epoch [25], train_loss: 0.5646, val_loss: 0.5471, val_acc: 0.7667
# Epoch [26], train_loss: 0.5325, val_loss: 0.5195, val_acc: 0.7667
# Epoch [27], train_loss: 0.5019, val_loss: 0.4976, val_acc: 0.7583
# Epoch [28], train_loss: 0.4722, val_loss: 0.4764, val_acc: 0.7500
# Epoch [29], train_loss: 0.4484, val_loss: 0.4569, val_acc: 0.7583
# Epoch [30], train_loss: 0.4312, val_loss: 0.4385, val_acc: 0.7583
# Epoch [31], train_loss: 0.4041, val_loss: 0.4236, val_acc: 0.7750
# Epoch [32], train_loss: 0.3764, val_loss: 0.4127, val_acc: 0.7750
# Epoch [33], train_loss: 0.3633, val_loss: 0.3952, val_acc: 0.7750
# Epoch [34], train_loss: 0.3516, val_loss: 0.3865, val_acc: 0.7750
# Epoch [35], train_loss: 0.3336, val_loss: 0.3732, val_acc: 0.7917
# Epoch [36], train_loss: 0.3333, val_loss: 0.3622, val_acc: 0.7917
# Epoch [37], train_loss: 0.3237, val_loss: 0.3697, val_acc: 0.7833
# Epoch [38], train_loss: 0.3079, val_loss: 0.3453, val_acc: 0.8000
# Epoch [39], train_loss: 0.3055, val_loss: 0.3466, val_acc: 0.8000
# Epoch [40], train_loss: 0.2980, val_loss: 0.3382, val_acc: 0.8000
# Epoch [41], train_loss: 0.2983, val_loss: 0.3301, val_acc: 0.8000
# Epoch [42], train_loss: 0.2845, val_loss: 0.3351, val_acc: 0.8083
# Epoch [43], train_loss: 0.2881, val_loss: 0.3228, val_acc: 0.8000
# Epoch [44], train_loss: 0.2754, val_loss: 0.3197, val_acc: 0.8083
# Epoch [45], train_loss: 0.2759, val_loss: 0.3219, val_acc: 0.8250
# Epoch [46], train_loss: 0.2720, val_loss: 0.3070, val_acc: 0.8000
# Epoch [47], train_loss: 0.2685, val_loss: 0.3186, val_acc: 0.8250
# Epoch [48], train_loss: 0.2784, val_loss: 0.3040, val_acc: 0.8000
# Epoch [49], train_loss: 0.2676, val_loss: 0.3145, val_acc: 0.8250
# Epoch [50], train_loss: 0.2594, val_loss: 0.2955, val_acc: 0.8083
# Epoch [51], train_loss: 0.2643, val_loss: 0.3041, val_acc: 0.8250
# Epoch [52], train_loss: 0.2611, val_loss: 0.2973, val_acc: 0.8250
# Epoch [53], train_loss: 0.2579, val_loss: 0.2941, val_acc: 0.8250
# Epoch [54], train_loss: 0.2532, val_loss: 0.2880, val_acc: 0.8083
# Epoch [55], train_loss: 0.2678, val_loss: 0.2837, val_acc: 0.8167
# Epoch [56], train_loss: 0.2577, val_loss: 0.3075, val_acc: 0.8667
# Epoch [57], train_loss: 0.2497, val_loss: 0.2765, val_acc: 0.8333
# Epoch [58], train_loss: 0.2477, val_loss: 0.2820, val_acc: 0.8417
# Epoch [59], train_loss: 0.2491, val_loss: 0.2898, val_acc: 0.8500
# Epoch [60], train_loss: 0.2467, val_loss: 0.2694, val_acc: 0.8250
# Epoch [61], train_loss: 0.2463, val_loss: 0.2797, val_acc: 0.8500
# Epoch [62], train_loss: 0.2493, val_loss: 0.2701, val_acc: 0.8500
# Epoch [63], train_loss: 0.2382, val_loss: 0.2777, val_acc: 0.8583
# Epoch [64], train_loss: 0.2455, val_loss: 0.2625, val_acc: 0.8417
# Epoch [65], train_loss: 0.2372, val_loss: 0.2695, val_acc: 0.8667
# Epoch [66], train_loss: 0.2355, val_loss: 0.2622, val_acc: 0.8667
# Epoch [67], train_loss: 0.2471, val_loss: 0.2581, val_acc: 0.8583
# Epoch [68], train_loss: 0.2294, val_loss: 0.2665, val_acc: 0.8750
# Epoch [69], train_loss: 0.2357, val_loss: 0.2554, val_acc: 0.8583
# Epoch [70], train_loss: 0.2332, val_loss: 0.2605, val_acc: 0.8833
# Epoch [71], train_loss: 0.2343, val_loss: 0.2446, val_acc: 0.8583
# Epoch [72], train_loss: 0.2268, val_loss: 0.2698, val_acc: 0.8750
# Epoch [73], train_loss: 0.2365, val_loss: 0.2460, val_acc: 0.8667
# Epoch [74], train_loss: 0.2242, val_loss: 0.2526, val_acc: 0.8833
# Epoch [75], train_loss: 0.2287, val_loss: 0.2422, val_acc: 0.8667
# Epoch [76], train_loss: 0.2165, val_loss: 0.2420, val_acc: 0.8750
# Epoch [77], train_loss: 0.2210, val_loss: 0.2438, val_acc: 0.8833
# Epoch [78], train_loss: 0.2230, val_loss: 0.2337, val_acc: 0.8667
# Epoch [79], train_loss: 0.2171, val_loss: 0.2574, val_acc: 0.8917
# Epoch [80], train_loss: 0.2164, val_loss: 0.2285, val_acc: 0.8750
# Epoch [81], train_loss: 0.2229, val_loss: 0.2352, val_acc: 0.8833
# Epoch [82], train_loss: 0.2213, val_loss: 0.2348, val_acc: 0.8833
# Epoch [83], train_loss: 0.2078, val_loss: 0.2238, val_acc: 0.8833
# Epoch [84], train_loss: 0.2235, val_loss: 0.2323, val_acc: 0.8833
# Epoch [85], train_loss: 0.2111, val_loss: 0.2337, val_acc: 0.9000
# Epoch [86], train_loss: 0.2024, val_loss: 0.2172, val_acc: 0.8917
# Epoch [87], train_loss: 0.2090, val_loss: 0.2282, val_acc: 0.8917
# Epoch [88], train_loss: 0.2122, val_loss: 0.2127, val_acc: 0.8917
# Epoch [89], train_loss: 0.2133, val_loss: 0.2166, val_acc: 0.8750
# Epoch [90], train_loss: 0.2001, val_loss: 0.2139, val_acc: 0.8917
# Epoch [91], train_loss: 0.2078, val_loss: 0.2119, val_acc: 0.8917
# Epoch [92], train_loss: 0.2086, val_loss: 0.2107, val_acc: 0.8833
# Epoch [93], train_loss: 0.2037, val_loss: 0.2108, val_acc: 0.8833
# Epoch [94], train_loss: 0.1986, val_loss: 0.2087, val_acc: 0.8833
# Epoch [95], train_loss: 0.1931, val_loss: 0.2032, val_acc: 0.8917
# Epoch [96], train_loss: 0.1894, val_loss: 0.2026, val_acc: 0.8917
# Epoch [97], train_loss: 0.1867, val_loss: 0.2003, val_acc: 0.8917
# Epoch [98], train_loss: 0.1920, val_loss: 0.1940, val_acc: 0.8917
# Epoch [99], train_loss: 0.1923, val_loss: 0.1999, val_acc: 0.9083
# Epoch [100], train_loss: 0.1894, val_loss: 0.1919, val_acc: 0.8917
# Epoch [101], train_loss: 0.1930, val_loss: 0.1884, val_acc: 0.8917
# Epoch [102], train_loss: 0.1957, val_loss: 0.1878, val_acc: 0.8917
# Epoch [103], train_loss: 0.1926, val_loss: 0.2014, val_acc: 0.9083
# Epoch [104], train_loss: 0.1767, val_loss: 0.1770, val_acc: 0.9333
# Epoch [105], train_loss: 0.1839, val_loss: 0.1960, val_acc: 0.9083
# Epoch [106], train_loss: 0.1773, val_loss: 0.1751, val_acc: 0.9083
# Epoch [107], train_loss: 0.1806, val_loss: 0.1918, val_acc: 0.9083
# Epoch [108], train_loss: 0.1804, val_loss: 0.1733, val_acc: 0.9083
# Epoch [109], train_loss: 0.1844, val_loss: 0.1843, val_acc: 0.9167
# Epoch [110], train_loss: 0.1792, val_loss: 0.1654, val_acc: 0.9500
# Epoch [111], train_loss: 0.1788, val_loss: 0.1827, val_acc: 0.9083
# Epoch [112], train_loss: 0.1767, val_loss: 0.1620, val_acc: 0.9333
# Epoch [113], train_loss: 0.1796, val_loss: 0.1653, val_acc: 0.9250
# Epoch [114], train_loss: 0.1745, val_loss: 0.1706, val_acc: 0.9167
# Epoch [115], train_loss: 0.1661, val_loss: 0.1611, val_acc: 0.9417
# Epoch [116], train_loss: 0.1689, val_loss: 0.1562, val_acc: 0.9333
# Epoch [117], train_loss: 0.1637, val_loss: 0.1596, val_acc: 0.9417
# Epoch [118], train_loss: 0.1651, val_loss: 0.1676, val_acc: 0.9250
# Epoch [119], train_loss: 0.1699, val_loss: 0.1526, val_acc: 0.9500
# Epoch [120], train_loss: 0.1638, val_loss: 0.1558, val_acc: 0.9417
# Epoch [121], train_loss: 0.1548, val_loss: 0.1492, val_acc: 0.9500
# Epoch [122], train_loss: 0.1587, val_loss: 0.1464, val_acc: 0.9500
# Epoch [123], train_loss: 0.1604, val_loss: 0.1503, val_acc: 0.9500
# Epoch [124], train_loss: 0.1502, val_loss: 0.1439, val_acc: 0.9500
# Epoch [125], train_loss: 0.1485, val_loss: 0.1475, val_acc: 0.9583
# Epoch [126], train_loss: 0.1532, val_loss: 0.1374, val_acc: 0.9417
# Epoch [127], train_loss: 0.1711, val_loss: 0.1480, val_acc: 0.9417
# Epoch [128], train_loss: 0.1539, val_loss: 0.1357, val_acc: 0.9583
# Epoch [129], train_loss: 0.1508, val_loss: 0.1386, val_acc: 0.9667
# Epoch [130], train_loss: 0.1486, val_loss: 0.1306, val_acc: 0.9500
# Epoch [131], train_loss: 0.1531, val_loss: 0.1338, val_acc: 0.9583
# Epoch [132], train_loss: 0.1591, val_loss: 0.1275, val_acc: 0.9417
# Epoch [133], train_loss: 0.1414, val_loss: 0.1364, val_acc: 0.9583
# Epoch [134], train_loss: 0.1467, val_loss: 0.1253, val_acc: 0.9500
# Epoch [135], train_loss: 0.1415, val_loss: 0.1286, val_acc: 0.9667
# Epoch [136], train_loss: 0.1465, val_loss: 0.1270, val_acc: 0.9667
# Epoch [137], train_loss: 0.1339, val_loss: 0.1245, val_acc: 0.9667
# Epoch [138], train_loss: 0.1363, val_loss: 0.1233, val_acc: 0.9583
# Epoch [139], train_loss: 0.1425, val_loss: 0.1181, val_acc: 0.9583
# Epoch [140], train_loss: 0.1408, val_loss: 0.1200, val_acc: 0.9583
# Epoch [141], train_loss: 0.1393, val_loss: 0.1211, val_acc: 0.9667
# Epoch [142], train_loss: 0.1354, val_loss: 0.1154, val_acc: 0.9667
# Epoch [143], train_loss: 0.1322, val_loss: 0.1184, val_acc: 0.9750
# Epoch [144], train_loss: 0.1346, val_loss: 0.1256, val_acc: 0.9667
# Epoch [145], train_loss: 0.1469, val_loss: 0.1116, val_acc: 0.9500
# Epoch [146], train_loss: 0.1350, val_loss: 0.1356, val_acc: 0.9500
# Epoch [147], train_loss: 0.1360, val_loss: 0.1121, val_acc: 0.9500
# Epoch [148], train_loss: 0.1313, val_loss: 0.1119, val_acc: 0.9667
# Epoch [149], train_loss: 0.1342, val_loss: 0.1109, val_acc: 0.9667
# Epoch [150], train_loss: 0.1248, val_loss: 0.1080, val_acc: 0.9750
# Epoch [151], train_loss: 0.1294, val_loss: 0.1075, val_acc: 0.9750
# Epoch [152], train_loss: 0.1456, val_loss: 0.1053, val_acc: 0.9583
# Epoch [153], train_loss: 0.1260, val_loss: 0.1228, val_acc: 0.9583
# Epoch [154], train_loss: 0.1223, val_loss: 0.1038, val_acc: 0.9583
# Epoch [155], train_loss: 0.1191, val_loss: 0.1104, val_acc: 0.9750
# Epoch [156], train_loss: 0.1296, val_loss: 0.1032, val_acc: 0.9750
# Epoch [157], train_loss: 0.1184, val_loss: 0.1048, val_acc: 0.9750
# Epoch [158], train_loss: 0.1266, val_loss: 0.1048, val_acc: 0.9750
# Epoch [159], train_loss: 0.1263, val_loss: 0.1003, val_acc: 0.9750
# Epoch [160], train_loss: 0.1219, val_loss: 0.1033, val_acc: 0.9750
# Epoch [161], train_loss: 0.1254, val_loss: 0.0993, val_acc: 0.9750
# Epoch [162], train_loss: 0.1244, val_loss: 0.0993, val_acc: 0.9667
# Epoch [163], train_loss: 0.1230, val_loss: 0.1021, val_acc: 0.9750
# Epoch [164], train_loss: 0.1153, val_loss: 0.0979, val_acc: 0.9667
# Epoch [165], train_loss: 0.1335, val_loss: 0.1006, val_acc: 0.9750
# Epoch [166], train_loss: 0.1189, val_loss: 0.0967, val_acc: 0.9667
# Epoch [167], train_loss: 0.1185, val_loss: 0.1009, val_acc: 0.9750
# Epoch [168], train_loss: 0.1155, val_loss: 0.0952, val_acc: 0.9750
# Epoch [169], train_loss: 0.1182, val_loss: 0.0941, val_acc: 0.9750
# Epoch [170], train_loss: 0.1163, val_loss: 0.0931, val_acc: 0.9750
# Epoch [171], train_loss: 0.1118, val_loss: 0.0940, val_acc: 0.9750
# Epoch [172], train_loss: 0.1065, val_loss: 0.0919, val_acc: 0.9750
# Epoch [173], train_loss: 0.1054, val_loss: 0.1005, val_acc: 0.9750
# Epoch [174], train_loss: 0.1140, val_loss: 0.0916, val_acc: 0.9750
# Epoch [175], train_loss: 0.1195, val_loss: 0.0946, val_acc: 0.9750
# Epoch [176], train_loss: 0.1073, val_loss: 0.0962, val_acc: 0.9750
# Epoch [177], train_loss: 0.1147, val_loss: 0.0904, val_acc: 0.9750
# Epoch [178], train_loss: 0.1073, val_loss: 0.0920, val_acc: 0.9750
# Epoch [179], train_loss: 0.1106, val_loss: 0.0885, val_acc: 0.9750
# Epoch [180], train_loss: 0.1101, val_loss: 0.0901, val_acc: 0.9750
# Epoch [181], train_loss: 0.1074, val_loss: 0.0882, val_acc: 0.9750
# Epoch [182], train_loss: 0.1157, val_loss: 0.0907, val_acc: 0.9750
# Epoch [183], train_loss: 0.1110, val_loss: 0.0878, val_acc: 0.9750
# Epoch [184], train_loss: 0.1024, val_loss: 0.0878, val_acc: 0.9833
# Epoch [185], train_loss: 0.1027, val_loss: 0.0889, val_acc: 0.9833
# Epoch [186], train_loss: 0.1042, val_loss: 0.0857, val_acc: 0.9750
# Epoch [187], train_loss: 0.1010, val_loss: 0.0861, val_acc: 0.9833
# Epoch [188], train_loss: 0.1056, val_loss: 0.0855, val_acc: 0.9833
# Epoch [189], train_loss: 0.1025, val_loss: 0.0936, val_acc: 0.9750
# Epoch [190], train_loss: 0.1159, val_loss: 0.0871, val_acc: 0.9750
# Epoch [191], train_loss: 0.1052, val_loss: 0.0868, val_acc: 0.9833
# Epoch [192], train_loss: 0.0978, val_loss: 0.0868, val_acc: 0.9833
# Epoch [193], train_loss: 0.0981, val_loss: 0.0830, val_acc: 0.9750
# Epoch [194], train_loss: 0.1047, val_loss: 0.0860, val_acc: 0.9833
# Epoch [195], train_loss: 0.0998, val_loss: 0.0830, val_acc: 0.9750
# Epoch [196], train_loss: 0.1017, val_loss: 0.0836, val_acc: 0.9833
# Epoch [197], train_loss: 0.0959, val_loss: 0.0886, val_acc: 0.9750
# Epoch [198], train_loss: 0.1009, val_loss: 0.0826, val_acc: 0.9750
# Epoch [199], train_loss: 0.1026, val_loss: 0.0833, val_acc: 0.9833

# %% [markdown]
# ### Test the model with test data

# %%
    
# Assuming evaluate function and model are defined elsewhere
print("Result from test data: ", evaluate(model, test_dl))

def display_images(images, labels, predictions):
    plt.figure(figsize=(10, 10))
    for i in range(36):
        plt.subplot(6, 6, i + 1)
        plt.imshow(images[i].permute(1, 2, 0))
        plt.title(f"Label: {labels[i]}\nPred: {predictions[i]}")
        plt.axis('off')
    plt.show()

# Get a batch of test data
test_images, test_labels = next(iter(test_dl))

# Move the batch to the same device as model and calculate predictions
test_images, test_labels = test_images.to(device), test_labels.to(device)
with torch.no_grad():
    model.eval()
    outputs = model(test_images)
    _, preds = torch.max(outputs, 1)

# Assuming 'device' is the device you're using (CPU or CUDA)
test_images, test_labels, preds = test_images.cpu(), test_labels.cpu(), preds.cpu()

# Display a 6x6 grid of test images with true and predicted labels
display_images(test_images, test_labels, preds)
# Out:
# Result from test data:  {'val_loss': 0.09436541050672531, 'val_acc': 0.9669421315193176}

# %% [markdown]
# ### Plots

# %%
# Plot loss- and validation loss for each epoch
tn = np.arange(1, len(history) + 1)
fig, ax1 = plt.subplots()
ax1.plot([x['val_loss'] for x in history], 'b', label="Loss")
ax1.plot(tn, [x['val_loss'] for x in history], '--', color='g', label="Validation Loss")
ax1.set_xlabel("Epochs"), ax1.set_ylabel("Loss")

# Plot accuracy- and validation accuracy for each epoch
ax2 = ax1.twinx()
ax2.plot([x['val_acc'] for x in history], 'r', label="Accuracy")
ax2.plot(tn, [x['val_acc'] for x in history], '--', color='y', label="Validation Accuracy")
ax2.set_ylabel("Accuracy")
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines+lines2, labels+labels2, loc='right')
plt.grid()
plt.title('Loss and accuracy for training and validation')
plot = plt.show()

# %% [markdown]
# ### Save the model

# %%
# Define the key for the model based on the hyperparameters and time
from datetime import date
import time
key = "CNN" + batch_size.__str__() + "_" + num_epochs.__str__() + "_" + lr.__str__() + "_" + opt_func.__name__ + "_" + date.today().__str__() + "_" + device.type +  "_" + time.strftime("%H_%M_%S")
print("Model key: ", key)

# ask if the user want to save the graph using input to /Users/bastiangraver/Desktop/6.Semester/BA Project/Model_Runs
# current folder /Users/bastiangraver/Desktop/6.Semester/BA Project/Python
save = input("Do you want to save the graph? (y/n): ")
if save == "y":
    plt.savefig(f"Model_Runs/{key}.png")
    print("Graph saved as: ", key + ".png")

# ask if the user wants to save the model using input
save = input("Do you want to save the model? (y/n): ")
if save == "y":
    torch.save(model.state_dict(), f"models/{key}.pth")
    print("Model saved as: ", key + ".pth")
else:
    print("Model not saved")
# Out:
# Model key:  CNN64_200_1e-05_Adam_2024-03-25_mps_14_33_36
# Model saved as:  CNN64_200_1e-05_Adam_2024-03-25_mps_14_33_36.pth
